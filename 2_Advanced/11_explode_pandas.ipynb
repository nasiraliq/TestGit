# %%
import pandas as pd

# Create the data
data = {
    'job_title': [
        'Data Scientist', 
        'Machine Learning Engineer', 
        'Data Analyst', 
        'Software Engineer', 
        'Business Analyst'
    ],
    'skills': [
        ['Python', 'Statistics', 'Data Visualization', 'Machine Learning'],
        ['Python', 'TensorFlow', 'PyTorch', 'Deep Learning'],
        ['SQL', 'Excel', 'Data Cleaning', 'Data Visualization'],
        ['Java', 'Python', 'Algorithms', 'System Design'],
        ['SQL', 'Business Strategy', 'Data Analysis', 'Communication']
    ]
}

# %%
data = pd.DataFrame(data)

# %%
data
# Out:
#                    job_title  \
# 0             Data Scientist
# 1  Machine Learning Engineer
# 2               Data Analyst
# 3          Software Engineer
# 4           Business Analyst
#
#                                               skills
# 0  [Python, Statistics, Data Visualization, Machi...
# 1       [Python, TensorFlow, PyTorch, Deep Learning]
# 2    [SQL, Excel, Data Cleaning, Data Visualization]
# 3          [Java, Python, Algorithms, System Design]
# 4  [SQL, Business Strategy, Data Analysis, Commun...

# %%
data.explode("skills")['skills'].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='skills'>
