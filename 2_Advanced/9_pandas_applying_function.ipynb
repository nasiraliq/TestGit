# %%
import pandas as pd
import ast
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../data/data_jobs.csv")

# %%
df["job_posted_date"] = pd.to_datetime(df["job_posted_date"])

# %%
df_new = df[df["salary_year_avg"].notna()].copy()
df_new.head(2)
# Out:
#    job_title_short            job_title  \
# 28  Data Scientist  CRM Data Specialist
# 77   Data Engineer        Data Engineer
#
#                                job_location          job_via  \
# 28  San José Province, San José, Costa Rica  via Ai-Jobs.net
# 77                            Arlington, VA     via LinkedIn
#
#    job_schedule_type  job_work_from_home search_location     job_posted_date  \
# 28         Full-time               False      Costa Rica 2023-08-01 13:37:57
# 77         Full-time               False           Sudan 2023-06-26 14:22:54
#
#     job_no_degree_mention  job_health_insurance job_country salary_rate  \
# 28                  False                 False  Costa Rica        year
# 77                  False                 False       Sudan        year
#
#     salary_year_avg  salary_hour_avg company_name  \
# 28         109500.0              NaN     Netskope
# 77         140000.0              NaN   Intelletec
#
# ...

# %%
df_new["salary_year_inflated"] = df_new["salary_year_avg"].apply(func=(lambda salary: salary* 1.03))
df_new.head(2)
# Out:
#    job_title_short            job_title  \
# 28  Data Scientist  CRM Data Specialist
# 77   Data Engineer        Data Engineer
#
#                                job_location          job_via  \
# 28  San José Province, San José, Costa Rica  via Ai-Jobs.net
# 77                            Arlington, VA     via LinkedIn
#
#    job_schedule_type  job_work_from_home search_location     job_posted_date  \
# 28         Full-time               False      Costa Rica 2023-08-01 13:37:57
# 77         Full-time               False           Sudan 2023-06-26 14:22:54
#
#     job_no_degree_mention  job_health_insurance job_country salary_rate  \
# 28                  False                 False  Costa Rica        year
# 77                  False                 False       Sudan        year
#
#     salary_year_avg  salary_hour_avg company_name  \
# 28         109500.0              NaN     Netskope
# 77         140000.0              NaN   Intelletec
#
# ...

# %%
df_new[["salary_year_avg", "salary_year_inflated"]].head()
# Out:
#      salary_year_avg  salary_year_inflated
# 28          109500.0             112785.00
# 77          140000.0             144200.00
# 92          120000.0             123600.00
# 100         228222.0             235068.66
# 109          89000.0              91670.00

# %%
df["job_skills"] = df["job_skills"].apply(func=(lambda skill: ast.literal_eval(skill) if pd.notna(skill) else skill) )

# %% [markdown]
# # Calculate Projected Salary next year
# - Senior roles assume 5%
# - Other roless assume 3%

# %%
# df[df["salary_year_avg"].notna()].head(5).apply(func=(lambda record : 1.05 * record["salary_year_avg"] if "Senior" in record["job_title_short"] else 1.03 * record["salary_year_avg"]))

# %%
df = df[df["salary_year_avg"].notna()]
